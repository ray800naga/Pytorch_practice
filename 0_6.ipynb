# %%
# %matplotlib inline

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
training_data = datasets.FashionMNIST(
    root='data',
    train=False,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root='data',
    train=False,
    download=True,
    transform=ToTensor()
)

train_dataloader = DataLoader(training_data, batch_size=64)
test_dataloader = DataLoader(test_data, batch_size=64)

class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10),
            nn.ReLU()
        )
    
    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork()

# %%
learning_rate = 1e-3
batch_size = 64
epochs = 5

# %%
# initialization and definition of loss function
loss_fn = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y), in enumerate(dataloader):
        # compute prediction and grads
        pred = model(X)
        loss = loss_fn(pred, y)

        # back prop.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f} [{current:>5d}/{size:>5d}]")

def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        test_loss /= size
        correct /= size
        print(f"Test Error:\n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f}\n")

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n--------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# --------------------------------
# loss: 2.056253 [    0/10000]
# loss: 1.979606 [ 6400/10000]
# Test Error:
#  Accuracy: 46.6%, Avg loss: 0.030898
#
# Epoch 2
# --------------------------------
# loss: 2.027170 [    0/10000]
# loss: 1.945502 [ 6400/10000]
# Test Error:
#  Accuracy: 46.9%, Avg loss: 0.030343
#
# Epoch 3
# --------------------------------
# loss: 1.997179 [    0/10000]
# loss: 1.911029 [ 6400/10000]
# Test Error:
#  Accuracy: 47.4%, Avg loss: 0.029787
#
# Epoch 4
# --------------------------------
# loss: 1.966964 [    0/10000]
# loss: 1.876776 [ 6400/10000]
# Test Error:
#  Accuracy: 47.7%, Avg loss: 0.029240
#
# Epoch 5
# --------------------------------
# loss: 1.936962 [    0/10000]
# loss: 1.843317 [ 6400/10000]
# Test Error:
#  Accuracy: 48.2%, Avg loss: 0.028709
#
# Epoch 6
# --------------------------------
# loss: 1.907640 [    0/10000]
# loss: 1.811194 [ 6400/10000]
# Test Error:
#  Accuracy: 48.7%, Avg loss: 0.028202
#
# Epoch 7
# --------------------------------
# loss: 1.879473 [    0/10000]
# loss: 1.780876 [ 6400/10000]
# Test Error:
#  Accuracy: 49.2%, Avg loss: 0.027720
#
# Epoch 8
# --------------------------------
# loss: 1.852741 [    0/10000]
# loss: 1.752703 [ 6400/10000]
# Test Error:
#  Accuracy: 49.6%, Avg loss: 0.027266
#
# Epoch 9
# --------------------------------
# loss: 1.827556 [    0/10000]
# loss: 1.726452 [ 6400/10000]
# Test Error:
#  Accuracy: 50.1%, Avg loss: 0.026839
#
# Epoch 10
# --------------------------------
# loss: 1.803869 [    0/10000]
# loss: 1.702082 [ 6400/10000]
# Test Error:
#  Accuracy: 50.7%, Avg loss: 0.026437
#
# Epoch 11
# --------------------------------
# loss: 1.781717 [    0/10000]
# loss: 1.679527 [ 6400/10000]
# Test Error:
#  Accuracy: 51.1%, Avg loss: 0.026059
#
# Epoch 12
# --------------------------------
# loss: 1.761027 [    0/10000]
# loss: 1.658546 [ 6400/10000]
# Test Error:
#  Accuracy: 51.5%, Avg loss: 0.025703
#
# Epoch 13
# --------------------------------
# loss: 1.741628 [    0/10000]
# loss: 1.638949 [ 6400/10000]
# Test Error:
#  Accuracy: 51.8%, Avg loss: 0.025367
#
# Epoch 14
# --------------------------------
# loss: 1.723356 [    0/10000]
# loss: 1.620460 [ 6400/10000]
# Test Error:
#  Accuracy: 52.1%, Avg loss: 0.025049
#
# Epoch 15
# --------------------------------
# loss: 1.706131 [    0/10000]
# loss: 1.603034 [ 6400/10000]
# Test Error:
#  Accuracy: 52.6%, Avg loss: 0.024747
#
# Epoch 16
# --------------------------------
# loss: 1.689824 [    0/10000]
# loss: 1.586444 [ 6400/10000]
# Test Error:
#  Accuracy: 53.1%, Avg loss: 0.024460
#
# Epoch 17
# --------------------------------
# loss: 1.674291 [    0/10000]
# loss: 1.570561 [ 6400/10000]
# Test Error:
#  Accuracy: 53.7%, Avg loss: 0.024186
#
# Epoch 18
# --------------------------------
# loss: 1.659471 [    0/10000]
# loss: 1.555334 [ 6400/10000]
# Test Error:
#  Accuracy: 54.1%, Avg loss: 0.023925
#
# Epoch 19
# --------------------------------
# loss: 1.645287 [    0/10000]
# loss: 1.540709 [ 6400/10000]
# Test Error:
#  Accuracy: 54.8%, Avg loss: 0.023676
#
# Epoch 20
# --------------------------------
# loss: 1.631761 [    0/10000]
# loss: 1.526657 [ 6400/10000]
# Test Error:
#  Accuracy: 55.4%, Avg loss: 0.023437
#
# Epoch 21
# --------------------------------
# loss: 1.618874 [    0/10000]
# loss: 1.512944 [ 6400/10000]
# Test Error:
#  Accuracy: 55.9%, Avg loss: 0.023210
#
# Epoch 22
# --------------------------------
# loss: 1.606601 [    0/10000]
# loss: 1.499759 [ 6400/10000]
# Test Error:
#  Accuracy: 56.3%, Avg loss: 0.022991
#
# Epoch 23
# --------------------------------
# loss: 1.594965 [    0/10000]
# loss: 1.487071 [ 6400/10000]
# Test Error:
#  Accuracy: 56.7%, Avg loss: 0.022783
#
# Epoch 24
# --------------------------------
# loss: 1.583863 [    0/10000]
# loss: 1.474802 [ 6400/10000]
# Test Error:
#  Accuracy: 57.2%, Avg loss: 0.022583
#
# Epoch 25
# --------------------------------
# loss: 1.573340 [    0/10000]
# loss: 1.462894 [ 6400/10000]
# Test Error:
#  Accuracy: 57.6%, Avg loss: 0.022391
#
# Epoch 26
# --------------------------------
# loss: 1.563359 [    0/10000]
# loss: 1.451435 [ 6400/10000]
# Test Error:
#  Accuracy: 58.0%, Avg loss: 0.022207
#
# Epoch 27
# --------------------------------
# loss: 1.553967 [    0/10000]
# loss: 1.440370 [ 6400/10000]
# Test Error:
#  Accuracy: 58.2%, Avg loss: 0.022031
#
# Epoch 28
# --------------------------------
# loss: 1.544939 [    0/10000]
# loss: 1.429680 [ 6400/10000]
# Test Error:
#  Accuracy: 58.4%, Avg loss: 0.021863
#
# Epoch 29
# --------------------------------
# loss: 1.536526 [    0/10000]
# loss: 1.419394 [ 6400/10000]
# Test Error:
#  Accuracy: 58.5%, Avg loss: 0.021703
#
# Epoch 30
# --------------------------------
# loss: 1.528570 [    0/10000]
# loss: 1.409413 [ 6400/10000]
# Test Error:
#  Accuracy: 58.7%, Avg loss: 0.021549
#
# Epoch 31
# --------------------------------
# loss: 1.520993 [    0/10000]
# loss: 1.399823 [ 6400/10000]
# Test Error:
#  Accuracy: 59.0%, Avg loss: 0.021401
#
# Epoch 32
# --------------------------------
# loss: 1.513784 [    0/10000]
# loss: 1.390562 [ 6400/10000]
# Test Error:
#  Accuracy: 59.2%, Avg loss: 0.021259
#
# Epoch 33
# --------------------------------
# loss: 1.506895 [    0/10000]
# loss: 1.381665 [ 6400/10000]
# Test Error:
#  Accuracy: 59.4%, Avg loss: 0.021124
#
# Epoch 34
# --------------------------------
# loss: 1.500370 [    0/10000]
# loss: 1.373068 [ 6400/10000]
# Test Error:
#  Accuracy: 59.6%, Avg loss: 0.020994
#
# Epoch 35
# --------------------------------
# loss: 1.494164 [    0/10000]
# loss: 1.364766 [ 6400/10000]
# Test Error:
#  Accuracy: 59.7%, Avg loss: 0.020868
#
# Epoch 36
# --------------------------------
# loss: 1.488271 [    0/10000]
# loss: 1.356804 [ 6400/10000]
# Test Error:
#  Accuracy: 59.9%, Avg loss: 0.020748
#
# Epoch 37
# --------------------------------
# loss: 1.482684 [    0/10000]
# loss: 1.349123 [ 6400/10000]
# Test Error:
#  Accuracy: 60.1%, Avg loss: 0.020633
#
# Epoch 38
# --------------------------------
# loss: 1.477387 [    0/10000]
# loss: 1.341730 [ 6400/10000]
# Test Error:
#  Accuracy: 60.3%, Avg loss: 0.020522
#
# Epoch 39
# --------------------------------
# loss: 1.472328 [    0/10000]
# loss: 1.334652 [ 6400/10000]
# Test Error:
#  Accuracy: 60.5%, Avg loss: 0.020416
#
# Epoch 40
# --------------------------------
# loss: 1.467592 [    0/10000]
# loss: 1.327817 [ 6400/10000]
# Test Error:
#  Accuracy: 60.7%, Avg loss: 0.020314
#
# Epoch 41
# --------------------------------
# loss: 1.463066 [    0/10000]
# loss: 1.321187 [ 6400/10000]
# Test Error:
#  Accuracy: 60.9%, Avg loss: 0.020216
#
# Epoch 42
# --------------------------------
# loss: 1.458771 [    0/10000]
# loss: 1.314875 [ 6400/10000]
# Test Error:
#  Accuracy: 61.0%, Avg loss: 0.020121
#
# Epoch 43
# --------------------------------
# loss: 1.454707 [    0/10000]
# loss: 1.308756 [ 6400/10000]
# Test Error:
#  Accuracy: 61.2%, Avg loss: 0.020031
#
# Epoch 44
# --------------------------------
# loss: 1.450911 [    0/10000]
# loss: 1.302883 [ 6400/10000]
# Test Error:
#  Accuracy: 61.3%, Avg loss: 0.019943
#
# Epoch 45
# --------------------------------
# loss: 1.447228 [    0/10000]
# loss: 1.297213 [ 6400/10000]
# Test Error:
#  Accuracy: 61.5%, Avg loss: 0.019859
#
# Epoch 46
# --------------------------------
# loss: 1.443752 [    0/10000]
# loss: 1.291746 [ 6400/10000]
# Test Error:
#  Accuracy: 61.5%, Avg loss: 0.019777
#
# Epoch 47
# --------------------------------
# loss: 1.440464 [    0/10000]
# loss: 1.286489 [ 6400/10000]
# Test Error:
#  Accuracy: 61.6%, Avg loss: 0.019699
#
# Epoch 48
# --------------------------------
# loss: 1.437273 [    0/10000]
# loss: 1.281460 [ 6400/10000]
# Test Error:
#  Accuracy: 61.8%, Avg loss: 0.019622
#
# Epoch 49
# --------------------------------
# loss: 1.434242 [    0/10000]
# loss: 1.276603 [ 6400/10000]
# Test Error:
#  Accuracy: 61.9%, Avg loss: 0.019549
#
# Epoch 50
# --------------------------------
# loss: 1.431312 [    0/10000]
# loss: 1.271999 [ 6400/10000]
# Test Error:
#  Accuracy: 62.0%, Avg loss: 0.019477
#
# Epoch 51
# --------------------------------
# loss: 1.428547 [    0/10000]
# loss: 1.267460 [ 6400/10000]
# Test Error:
#  Accuracy: 62.2%, Avg loss: 0.019408
#
# Epoch 52
# --------------------------------
# loss: 1.425824 [    0/10000]
# loss: 1.263104 [ 6400/10000]
# Test Error:
#  Accuracy: 62.4%, Avg loss: 0.019340
#
# Epoch 53
# --------------------------------
# loss: 1.423282 [    0/10000]
# loss: 1.258854 [ 6400/10000]
# Test Error:
#  Accuracy: 62.4%, Avg loss: 0.019274
#
# Epoch 54
# --------------------------------
# loss: 1.420783 [    0/10000]
# loss: 1.254740 [ 6400/10000]
# Test Error:
#  Accuracy: 62.5%, Avg loss: 0.019210
#
# Epoch 55
# --------------------------------
# loss: 1.418179 [    0/10000]
# loss: 1.250814 [ 6400/10000]
# Test Error:
#  Accuracy: 62.6%, Avg loss: 0.019148
#
# Epoch 56
# --------------------------------
# loss: 1.415852 [    0/10000]
# loss: 1.247002 [ 6400/10000]
# Test Error:
#  Accuracy: 62.7%, Avg loss: 0.019087
#
# Epoch 57
# --------------------------------
# loss: 1.413581 [    0/10000]
# loss: 1.243253 [ 6400/10000]
# Test Error:
#  Accuracy: 62.9%, Avg loss: 0.019028
#
# Epoch 58
# --------------------------------
# loss: 1.411319 [    0/10000]
# loss: 1.239609 [ 6400/10000]
# Test Error:
#  Accuracy: 63.0%, Avg loss: 0.018970
#
# Epoch 59
# --------------------------------
# loss: 1.409139 [    0/10000]
# loss: 1.236062 [ 6400/10000]
# Test Error:
#  Accuracy: 63.2%, Avg loss: 0.018914
#
# Epoch 60
# --------------------------------
# loss: 1.406979 [    0/10000]
# loss: 1.232573 [ 6400/10000]
# Test Error:
#  Accuracy: 63.3%, Avg loss: 0.018858
#
# Epoch 61
# --------------------------------
# loss: 1.404911 [    0/10000]
# loss: 1.229218 [ 6400/10000]
# Test Error:
#  Accuracy: 63.5%, Avg loss: 0.018803
#
# Epoch 62
# --------------------------------
# loss: 1.402853 [    0/10000]
# loss: 1.225917 [ 6400/10000]
# Test Error:
#  Accuracy: 63.6%, Avg loss: 0.018750
#
# Epoch 63
# --------------------------------
# loss: 1.400841 [    0/10000]
# loss: 1.222708 [ 6400/10000]
# Test Error:
#  Accuracy: 63.7%, Avg loss: 0.018698
#
# Epoch 64
# --------------------------------
# loss: 1.398942 [    0/10000]
# loss: 1.219573 [ 6400/10000]
# Test Error:
#  Accuracy: 63.8%, Avg loss: 0.018646
#
# Epoch 65
# --------------------------------
# loss: 1.396963 [    0/10000]
# loss: 1.216518 [ 6400/10000]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 0.018595
#
# Epoch 66
# --------------------------------
# loss: 1.395064 [    0/10000]
# loss: 1.213521 [ 6400/10000]
# Test Error:
#  Accuracy: 64.1%, Avg loss: 0.018545
#
# Epoch 67
# --------------------------------
# loss: 1.393093 [    0/10000]
# loss: 1.210577 [ 6400/10000]
# Test Error:
#  Accuracy: 64.1%, Avg loss: 0.018495
#
# Epoch 68
# --------------------------------
# loss: 1.391195 [    0/10000]
# loss: 1.207612 [ 6400/10000]
# Test Error:
#  Accuracy: 64.2%, Avg loss: 0.018446
#
# Epoch 69
# --------------------------------
# loss: 1.389234 [    0/10000]
# loss: 1.204779 [ 6400/10000]
# Test Error:
#  Accuracy: 64.3%, Avg loss: 0.018398
#
# Epoch 70
# --------------------------------
# loss: 1.387368 [    0/10000]
# loss: 1.202013 [ 6400/10000]
# Test Error:
#  Accuracy: 64.4%, Avg loss: 0.018350
#
# Epoch 71
# --------------------------------
# loss: 1.385488 [    0/10000]
# loss: 1.199276 [ 6400/10000]
# Test Error:
#  Accuracy: 64.5%, Avg loss: 0.018303
#
# Epoch 72
# --------------------------------
# loss: 1.383617 [    0/10000]
# loss: 1.196569 [ 6400/10000]
# Test Error:
#  Accuracy: 64.6%, Avg loss: 0.018257
#
# Epoch 73
# --------------------------------
# loss: 1.381770 [    0/10000]
# loss: 1.193938 [ 6400/10000]
# Test Error:
#  Accuracy: 64.7%, Avg loss: 0.018210
#
# Epoch 74
# --------------------------------
# loss: 1.379910 [    0/10000]
# loss: 1.191365 [ 6400/10000]
# Test Error:
#  Accuracy: 64.8%, Avg loss: 0.018165
#
# Epoch 75
# --------------------------------
# loss: 1.378056 [    0/10000]
# loss: 1.188836 [ 6400/10000]
# Test Error:
#  Accuracy: 64.8%, Avg loss: 0.018119
#
# Epoch 76
# --------------------------------
# loss: 1.376265 [    0/10000]
# loss: 1.186307 [ 6400/10000]
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.018074
#
# Epoch 77
# --------------------------------
# loss: 1.374478 [    0/10000]
# loss: 1.183834 [ 6400/10000]
# Test Error:
#  Accuracy: 65.0%, Avg loss: 0.018030
#
# Epoch 78
# --------------------------------
# loss: 1.372732 [    0/10000]
# loss: 1.181421 [ 6400/10000]
# Test Error:
#  Accuracy: 65.1%, Avg loss: 0.017985
#
# Epoch 79
# --------------------------------
# loss: 1.371194 [    0/10000]
# loss: 1.178980 [ 6400/10000]
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.017941
#
# Epoch 80
# --------------------------------
# loss: 1.369496 [    0/10000]
# loss: 1.176613 [ 6400/10000]
# Test Error:
#  Accuracy: 65.3%, Avg loss: 0.017898
#
# Epoch 81
# --------------------------------
# loss: 1.367738 [    0/10000]
# loss: 1.174212 [ 6400/10000]
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.017854
#
# Epoch 82
# --------------------------------
# loss: 1.365981 [    0/10000]
# loss: 1.171878 [ 6400/10000]
# Test Error:
#  Accuracy: 65.5%, Avg loss: 0.017811
#
# Epoch 83
# --------------------------------
# loss: 1.364257 [    0/10000]
# loss: 1.169551 [ 6400/10000]
# Test Error:
#  Accuracy: 65.6%, Avg loss: 0.017768
#
# Epoch 84
# --------------------------------
# loss: 1.362363 [    0/10000]
# loss: 1.167240 [ 6400/10000]
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.017725
#
# Epoch 85
# --------------------------------
# loss: 1.360551 [    0/10000]
# loss: 1.164982 [ 6400/10000]
# Test Error:
#  Accuracy: 65.7%, Avg loss: 0.017683
#
# Epoch 86
# --------------------------------
# loss: 1.358771 [    0/10000]
# loss: 1.162760 [ 6400/10000]
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.017641
#
# Epoch 87
# --------------------------------
# loss: 1.357046 [    0/10000]
# loss: 1.160560 [ 6400/10000]
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.017599
#
# Epoch 88
# --------------------------------
# loss: 1.355361 [    0/10000]
# loss: 1.158327 [ 6400/10000]
# Test Error:
#  Accuracy: 65.9%, Avg loss: 0.017557
#
# Epoch 89
# --------------------------------
# loss: 1.353640 [    0/10000]
# loss: 1.156154 [ 6400/10000]
# Test Error:
#  Accuracy: 65.9%, Avg loss: 0.017516
#
# Epoch 90
# --------------------------------
# loss: 1.351901 [    0/10000]
# loss: 1.154064 [ 6400/10000]
# Test Error:
#  Accuracy: 65.9%, Avg loss: 0.017475
#
# Epoch 91
# --------------------------------
# loss: 1.350223 [    0/10000]
# loss: 1.151872 [ 6400/10000]
# Test Error:
#  Accuracy: 65.9%, Avg loss: 0.017434
#
# Epoch 92
# --------------------------------
# loss: 1.348441 [    0/10000]
# loss: 1.149726 [ 6400/10000]
# Test Error:
#  Accuracy: 66.0%, Avg loss: 0.017394
#
# Epoch 93
# --------------------------------
# loss: 1.346651 [    0/10000]
# loss: 1.147581 [ 6400/10000]
# Test Error:
#  Accuracy: 66.1%, Avg loss: 0.017353
#
# Epoch 94
# --------------------------------
# loss: 1.344868 [    0/10000]
# loss: 1.145450 [ 6400/10000]
# Test Error:
#  Accuracy: 66.2%, Avg loss: 0.017313
#
# Epoch 95
# --------------------------------
# loss: 1.343050 [    0/10000]
# loss: 1.143316 [ 6400/10000]
# Test Error:
#  Accuracy: 66.2%, Avg loss: 0.017273
#
# Epoch 96
# --------------------------------
# loss: 1.341179 [    0/10000]
# loss: 1.141229 [ 6400/10000]
# Test Error:
#  Accuracy: 66.2%, Avg loss: 0.017234
#
# Epoch 97
# --------------------------------
# loss: 1.339341 [    0/10000]
# loss: 1.139158 [ 6400/10000]
# Test Error:
#  Accuracy: 66.3%, Avg loss: 0.017194
#
# Epoch 98
# --------------------------------
# loss: 1.337482 [    0/10000]
# loss: 1.137140 [ 6400/10000]
# Test Error:
#  Accuracy: 66.4%, Avg loss: 0.017155
#
# Epoch 99
# --------------------------------
# loss: 1.335815 [    0/10000]
# loss: 1.135086 [ 6400/10000]
# Test Error:
#  Accuracy: 66.4%, Avg loss: 0.017117
#
# Epoch 100
# --------------------------------
# loss: 1.333969 [    0/10000]
# loss: 1.132967 [ 6400/10000]
# Test Error:
#  Accuracy: 66.5%, Avg loss: 0.017078
#
# Done!
